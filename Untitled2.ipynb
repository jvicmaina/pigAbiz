# %%
pip install bing-image-downloader
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !mkdir pig_images

# %%
# !apt-get -qq install -y libarchive-dev && pip install -U libarchive
import libarchive
# Out:
# Selecting previously unselected package libarchive-dev:amd64.
# (Reading database ... 155222 files and directories currently installed.)
# Preparing to unpack .../libarchive-dev_3.2.2-3.1ubuntu0.7_amd64.deb ...
# Unpacking libarchive-dev:amd64 (3.2.2-3.1ubuntu0.7) ...
# Setting up libarchive-dev:amd64 (3.2.2-3.1ubuntu0.7) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# ...
#      |████████████████████████████████| 154 kB 6.3 MB/s
# ...
#   Created wheel for libarchive: filename=libarchive-0.4.7-py3-none-any.whl size=31647 sha256=6969242eb9cfd3e8bf18982f9261d13a455ce785d35faa717e85091f2918d109
#   Stored in directory: /root/.cache/pip/wheels/63/b1/c6/b3da79bec2012175bd43603eed98ef8548ac1733b77c1d4330
# Successfully built libarchive
# ...

# %%
# !apt-get -qq install -y graphviz && pip install pydot
import pydot

# %%
# !pip install cartopy
import cartopy

# %%
from bing_image_downloader import downloader
downloader.download("duroc pigs", limit=100,  output_dir='large_white', adult_filter_off=True, force_replace=False, timeout=60, verbose=True)
# Out:
# [%] Downloading Images to /content/large_white/duroc pigs
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 100 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://img-aws.ehowcdn.com/600x400/photos.demandstudios.com/getty/article/108/75/538338851.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.shbshowpigs.com/uploads/1/2/0/8/12089131/8953105_orig.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://morningchores.com/wp-content/uploads/2021/01/DSC_0801-1536x1024.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from http://s24990.pcdn.co/wp-content/uploads/2017/10/hulk-pigs-Cambodia-1-1024x538.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from http://2.bp.blogspot.com/-nZK2VTTw5Lo/T_-WIov5BQI/AAAAAAAADTw/4fItcDZ1wFQ/s1600/106_2283.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://1.bp.blogspot.com/-GtJV6zIf4UU/T43kF1MO22I/AAAAAAAAACE/XUiiMq_0ox8/s1600/pigs%2Band%2Bgrandkids%2B064.JPG
# ...

# %%
# !mkdir hampshire

# %%
from bing_image_downloader import downloader
downloader.download("hampshire pigs", limit=100,  output_dir='hampshire', adult_filter_off=True, force_replace=False, timeout=60, verbose=True)
# Out:
# [%] Downloading Images to /content/hampshire/hampshire pigs
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 100 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://www.britishpigs.org.uk/images/2020/04/02/hampshire-pig.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://s-media-cache-ak0.pinimg.com/originals/94/69/21/94692171ee2ca521c262bf44ec8a5986.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://eggersshowpigs.com/images/2013/02-27-13/IMG_5990.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from http://www.brinkgenetics.com/images/swine/females/JDB-5F109-4.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from http://eggersshowpigs.com/images/boars/5pic16C.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from http://www.shipleyswine.com/Boars/Exotic/Lawless/Large/Lawless2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #7 from https://i.pinimg.com/originals/9c/e1/cc/9ce1cc41359d2d38bba750eb2f2d66a1.jpg
# ...

# %%
# !mkdir landrace

# %%
from bing_image_downloader import downloader
downloader.download("landrace pigs", limit=100,  output_dir='landrace', adult_filter_off=True, force_replace=False, timeout=60, verbose=True)
# Out:
# [%] Downloading Images to /content/landrace/landrace pigs
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 100 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from http://topcutgeneticsllc.com/sires/landrace/Vantage-point.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://upload.wikimedia.org/wikipedia/commons/thumb/2/24/Truie_Landrace.jpg/320px-Truie_Landrace.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://ntgh.org/wp-content/uploads/2021/06/1624774106_160_American-Landrace-Pig-Breed-Information-and-Guide.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from http://www.brinkgenetics.com/images/swine/females/hamplandrace.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://s-media-cache-ak0.pinimg.com/originals/c2/e3/1c/c2e31c1b3a0fc92ecd3b63c0aff17ca8.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from http://shaffergoldrush.com/pagebuilder/animals/1pic247.jpg
# [%] File Downloaded !
#
# ...

# %%
# !mkdir large_white
# Out:
# mkdir: cannot create directory ‘large_white’: File exists

# %%
from bing_image_downloader import downloader
downloader.download("large white pigs", limit=100,  output_dir='large_white', adult_filter_off=True, force_replace=False, timeout=60, verbose=True)
# Out:
# [%] Downloading Images to /content/large_white/large white pigs
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 100 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://alchetron.com/cdn/large-white-pig-1fe5d920-247a-43c3-9471-40f1ac3e1ec-resize-750.jpeg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://www.qnxdtrade.com/pic/big/17_0.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://s3.amazonaws.com/fallingrain/uploads/003e64574efd4658a51427e69dac8aae/original/open-uri20170725-27-1mimif0?1501021128
# [%] File Downloaded !
#
# [%] Downloading Image #4 from http://sugarmtnfarm.com/blog/uploaded_images2015/ClassicYorkshireSow1899w.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://static.wixstatic.com/media/177284_3ed5c6defd324d559431f9362c63b8ab.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://i.ebayimg.com/images/g/yLYAAOSwZEde35cs/s-l400.jpg
# [%] File Downloaded !
#
# ...

# %%
from bing_image_downloader import downloader
downloader.download("pig images", limit=100,  output_dir='pig_images', adult_filter_off=True, force_replace=False, timeout=60, verbose=True)

# %%
from bing_image_downloader import downloader
downloader.download("pig images", limit=100,  output_dir='pig_images', adult_filter_off=True, force_replace=False, timeout=60, verbose=True)
# Out:
# [%] Downloading Images to /content/pig_images/pig images
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 100 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://www.rd.com/wp-content/uploads/2017/08/Thanks-to-Science-Your-Next-Organ-Donor-Could-Be-a-Pig-_556381594_HQuality-1024x682.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://animalia-life.com/data_images/pig/pig7.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://i.redd.it/qebzfkbuhzl31.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://cdn.roaring.earth/wp-content/uploads/2015/09/cenote.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://irishhistorypodcast.ie/wp-content/uploads/2013/04/pig.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://4.bp.blogspot.com/-doY9HHvne0A/T7JyjO3p98I/AAAAAAAAAA4/sdSUjwx9Dv8/s1600/Marchapril2011+260.jpg
# [%] File Downloaded !
#
# ...

# %%
# !mkdir large_white
